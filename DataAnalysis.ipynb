# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_info_columns', 1000)
df = pd.read_csv("data.csv")
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  \
# 0        170         72   Argentina         FC Barcelona
# ...

# %%
df.shape
# Out:
# (18944, 106)

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg   league_rank  \
# count   18944.000000  18944.000000  18944.000000  18944.000000  18719.000000
# mean   226242.402872     25.225823    181.190773     75.016892      1.357070
# std     27171.091056      4.697354      6.825672      7.057140      0.739327
# min        41.000000     16.000000    155.000000     50.000000      1.000000
# 25%    210030.500000     21.000000    176.000000     70.000000      1.000000
# 50%    232314.500000     25.000000    181.000000     75.000000      1.000000
# 75%    246760.250000     29.000000    186.000000     80.000000      1.000000
# max    258970.000000     53.000000    206.000000    110.000000      4.000000
#
#             overall     potential     value_eur       wage_eur  \
# count  18944.000000  18944.000000  1.894400e+04   18944.000000
# mean      65.677787     71.086729  2.224813e+06    8675.852513
# std        7.002278      6.109985  5.102486e+06   19654.774894
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 106 columns):
#  #    Column                      Non-Null Count  Dtype
# ---   ------                      --------------  -----
#  0    sofifa_id                   18944 non-null  int64
#  1    player_url                  18944 non-null  object
#  2    short_name                  18944 non-null  object
#  3    long_name                   18944 non-null  object
#  4    age                         18944 non-null  int64
#  5    dob                         18944 non-null  object
#  6    height_cm                   18944 non-null  int64
#  7    weight_kg                   18944 non-null  int64
#  8    nationality                 18944 non-null  object
#  9    club_name                   18719 non-null  object
#  10   league_name                 18719 non-null  object
#  11   league_rank                 18719 non-null  float64
#  12   overall                     18944 non-null  int64
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
# removing irrelevant columns
df=df[['sofifa_id', 'short_name', 'age', 'dob',
       'height_cm', 'weight_kg', 'nationality', 'club_name',
       'league_name', 'league_rank', 'overall', 'potential', 'skill_moves', 'pace', 'shooting', 'passing', 'dribbling',
       'defending', 'physic', 'player_traits',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_short_passing',
       'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed',
       'movement_agility', 'power_stamina',
       'power_strength', 'mentality_aggression',
       'mentality_vision', 'mentality_composure',]]
df
# Out:
#        sofifa_id         short_name  age         dob  height_cm  weight_kg  \
# 0         158023           L. Messi   33  1987-06-24        170         72
# 1          20801  Cristiano Ronaldo   35  1985-02-05        187         83
# 2         200389           J. Oblak   27  1993-01-07        188         87
# 3         188545     R. Lewandowski   31  1988-08-21        184         80
# 4         190871          Neymar Jr   28  1992-02-05        175         68
# ...          ...                ...  ...         ...        ...        ...
# 18939     256679          K. Angulo   24  1996-04-13        176         73
# 18940     257710     Zhang Mengxuan   21  1999-04-26        177         70
# 18941     250989      Wang Zhenghao   20  2000-06-28        185         74
# 18942     257697        Chen Zitong   23  1997-02-20        186         80
# 18943     257936           Song Yue   28  1991-11-20        185         79
#
#       nationality                            club_name  \
# ...

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   sofifa_id                   18944 non-null  int64
#  1   short_name                  18944 non-null  object
#  2   age                         18944 non-null  int64
#  3   dob                         18944 non-null  object
#  4   height_cm                   18944 non-null  int64
#  5   weight_kg                   18944 non-null  int64
#  6   nationality                 18944 non-null  object
#  7   club_name                   18719 non-null  object
#  8   league_name                 18719 non-null  object
#  9   league_rank                 18719 non-null  float64
#  10  overall                     18944 non-null  int64
#  11  potential                   18944 non-null  int64
#  12  skill_moves                 18944 non-null  int64
# ...

# %%
# Dropping rows with missing values
df.replace("", np.nan, inplace=True)
df.dropna(axis=0, inplace=True)

# %%
# Converting and height and weight columns to float
df['height_cm']=df['height_cm'].astype(float)
df['weight_kg']=df['weight_kg'].astype(float)
df
# Out:
#        sofifa_id         short_name  age         dob  height_cm  weight_kg  \
# 0         158023           L. Messi   33  1987-06-24      170.0       72.0
# 1          20801  Cristiano Ronaldo   35  1985-02-05      187.0       83.0
# 3         188545     R. Lewandowski   31  1988-08-21      184.0       80.0
# 4         190871          Neymar Jr   28  1992-02-05      175.0       68.0
# 5         192985       K. De Bruyne   29  1991-06-28      181.0       70.0
# ...          ...                ...  ...         ...        ...        ...
# 18704     256484        E. Johnston   18  2002-06-13      180.0       73.0
# 18706     256667            A. Cano   19  2001-06-08      186.0       78.0
# 18825     247038            J. Haak   18  2001-09-12      184.0       75.0
# 18836     252466           D. Bouah   18  2001-08-13      177.0       74.0
# 18915     251110       Wang Haijian   19  2000-08-02      185.0       67.0
#
# ...

# %%
# Plotting a regression plot of mentality_vision against a player's overall performance
sns.regplot(x=df["mentality_vision"], y=df["overall"], line_kws={"color": "purple"})
# Out:
# <Axes: xlabel='mentality_vision', ylabel='overall'>

# %%
# Plotting a regression plot of dribbling against a player's overall performance
sns.regplot(x=df["dribbling"], y=df["overall"], line_kws={"color": "purple"})
# Out:
# <Axes: xlabel='dribbling', ylabel='overall'>

# %%
# Plotting a Histogram to show distribution of the players' ages using matplotlib
plt.figure(figsize=(8,8))
n, bins, edges= plt.hist(df['age'], bins=10, edgecolor="black")
plt.xticks(np.round(bins,0))
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Distribution of Players' Ages")
plt.show()

# %%
# Plotting a scatter plot to show how the player's weights and heights are correlated using matplotlib
plt.figure(figsize=(8,8))
plt.scatter(x=df['weight_kg'], y=df['height_cm'])
plt.xlabel('Weight in Kg')
plt.ylabel('Height in cm')
plt.title('Scatter Plot of Weight Against Height')
plt.show()
